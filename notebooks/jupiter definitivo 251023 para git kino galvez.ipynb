# %% [markdown]
# mi jupyter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import squarify
import seaborn as sns

# %%
df_ufo_nuforc = pd.read_csv('../data/mundo_nuforc_events.csv') # index_col = 0.............dataset sin limpiar de khturner...scrap de nuforc
df_ufo_nuforc
# Out:
#                   Event_Time  Event_Date    Year  Month   Day  Hour  Minute  \
# 0       2017-04-20T14:15:00Z  2017-04-20  2017.0    4.0  20.0  14.0    15.0
# 1       2017-04-20T04:56:00Z  2017-04-20  2017.0    4.0  20.0   4.0    56.0
# 2       2017-04-19T23:55:00Z  2017-04-19  2017.0    4.0  19.0  23.0    55.0
# 3       2017-04-19T23:50:00Z  2017-04-19  2017.0    4.0  19.0  23.0    50.0
# 4       2017-04-19T23:29:00Z  2017-04-19  2017.0    4.0  19.0  23.0    29.0
# ...                      ...         ...     ...    ...   ...   ...     ...
# 110260                   NaN         NaN     NaN    NaN   NaN   NaN     NaN
# 110261                   NaN         NaN     NaN    NaN   NaN   NaN     NaN
# 110262                   NaN         NaN     NaN    NaN   NaN   NaN     NaN
# 110263                   NaN         NaN     NaN    NaN   NaN   NaN     NaN
# 110264                   NaN         NaN     NaN    NaN   NaN   NaN     NaN
#
#               City State     Shape     Duration  \
# 0          Palmyra    NJ     Other    5 minutes
# 1       Bridgeview    IL     Light   20 seconds
# 2           Newton    AL  Triangle    5 seconds
# 3           Newton    AL  Triangle  5-6 minutes
# 4           Denver    CO     Light       1 hour
# ...            ...   ...       ...          ...
# 110260         NaN   NaN  Cylinder          NaN
# 110261        Rule    TX   Unknown   15 minutes
# 110262    Subotica   NaN       NaN          NaN
# 110263    Key West    FL     Other   one minute
# 110264    Richland    WA    Sphere       10 min
#
#                                                   Summary  \
# 0         I observed an aircraft that seemed to look odd.
# 1       Bridgeview, IL, blue light.  ((anonymous report))
# 2                                    Silent triangle UFO.
# 3       My friend and I stepped outside hoping to catc...
# 4       Moved slow but made quick turns staying and ci...
# ...                                                   ...
# 110260  I video taped a UFO off the tv (cnn/headline n...
# 110261  Unusual sounds and starlight distortion defini...
# 110262  Objects was moving very fast on this about pos...
# 110263  I lived on a shallow-water marshland in Key We...
# 110264                                 Multiple sightings
#
#                                                 Event_URL
# 0       http://www.nuforc.org/webreports/133/S133726.html
# 1       http://www.nuforc.org/webreports/133/S133720.html
# 2       http://www.nuforc.org/webreports/133/S133724.html
# 3       http://www.nuforc.org/webreports/133/S133723.html
# 4       http://www.nuforc.org/webreports/133/S133721.html
# ...                                                   ...
# 110260   http://www.nuforc.org/webreports/032/S32416.html
# 110261   http://www.nuforc.org/webreports/091/S91521.html
# 110262   http://www.nuforc.org/webreports/086/S86594.html
# 110263   http://www.nuforc.org/webreports/034/S34436.html
# 110264   http://www.nuforc.org/webreports/087/S87806.html
#
# [110265 rows x 13 columns]

# %%
df_ufo_nuforc.head(10)
# Out:
#              Event_Time  Event_Date    Year  Month   Day  Hour  Minute  \
# 0  2017-04-20T14:15:00Z  2017-04-20  2017.0    4.0  20.0  14.0    15.0
# 1  2017-04-20T04:56:00Z  2017-04-20  2017.0    4.0  20.0   4.0    56.0
# 2  2017-04-19T23:55:00Z  2017-04-19  2017.0    4.0  19.0  23.0    55.0
# 3  2017-04-19T23:50:00Z  2017-04-19  2017.0    4.0  19.0  23.0    50.0
# 4  2017-04-19T23:29:00Z  2017-04-19  2017.0    4.0  19.0  23.0    29.0
# 5  2017-04-19T21:45:00Z  2017-04-19  2017.0    4.0  19.0  21.0    45.0
# 6  2017-04-19T20:50:00Z  2017-04-19  2017.0    4.0  19.0  20.0    50.0
# 7  2017-04-19T20:50:00Z  2017-04-19  2017.0    4.0  19.0  20.0    50.0
# 8  2017-04-19T20:30:00Z  2017-04-19  2017.0    4.0  19.0  20.0    30.0
# 9  2017-04-19T20:10:00Z  2017-04-19  2017.0    4.0  19.0  20.0    10.0
#
#                  City State     Shape     Duration  \
# 0             Palmyra    NJ     Other    5 minutes
# 1          Bridgeview    IL     Light   20 seconds
# 2              Newton    AL  Triangle    5 seconds
# 3              Newton    AL  Triangle  5-6 minutes
# 4              Denver    CO     Light       1 hour
# 5    Cobourg (Canada)    ON     Light    4 minutes
# 6         Garden City    SC    Sphere   20 seconds
# 7  North Myrtle Beach    SC     Light     1 minute
# 8      Surfside Beach    SC    Circle   15 seconds
# 9  Chiba City (Japan)   NaN   Unknown    3 seconds
#
#                                              Summary  \
# 0    I observed an aircraft that seemed to look odd.
# 1  Bridgeview, IL, blue light.  ((anonymous report))
# 2                               Silent triangle UFO.
# 3  My friend and I stepped outside hoping to catc...
# 4  Moved slow but made quick turns staying and ci...
# 5  Two "satellites" traving S in tandem, then re...
# 6  Five bright orange orbs appear quietly over wa...
# 7  Orange Orbs Spotted Over North Myrtle Beach......
# 8  Single orb over ocean, moved north, 5 orbs for...
# 9  I saw a fast pretty round object from the othe...
#
#                                            Event_URL
# 0  http://www.nuforc.org/webreports/133/S133726.html
# 1  http://www.nuforc.org/webreports/133/S133720.html
# 2  http://www.nuforc.org/webreports/133/S133724.html
# 3  http://www.nuforc.org/webreports/133/S133723.html
# 4  http://www.nuforc.org/webreports/133/S133721.html
# 5  http://www.nuforc.org/webreports/133/S133715.html
# 6  http://www.nuforc.org/webreports/133/S133718.html
# 7  http://www.nuforc.org/webreports/133/S133716.html
# 8  http://www.nuforc.org/webreports/133/S133713.html
# 9  http://www.nuforc.org/webreports/133/S133703.html

# %%
df_ufo_nuforc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110265 entries, 0 to 110264
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Event_Time  108575 non-null  object
#  1   Event_Date  110012 non-null  object
#  2   Year        110012 non-null  float64
#  3   Month       110012 non-null  float64
#  4   Day         110163 non-null  float64
#  5   Hour        108685 non-null  float64
#  6   Minute      108677 non-null  float64
#  7   City        110033 non-null  object
#  8   State       101961 non-null  object
#  9   Shape       106790 non-null  object
#  10  Duration    106103 non-null  object
#  11  Summary     110229 non-null  object
#  12  Event_URL   110265 non-null  object
# dtypes: float64(5), object(8)
# memory usage: 10.9+ MB

# %%
#Compruebo si puedo aprovechar la columna Event_Time, para rellenar Hour o Minute
df_ufo_nuforc[df_ufo_nuforc['Hour'].isnull() & df_ufo_nuforc['Minute'].isnull() & df_ufo_nuforc['Event_Time'].notnull()]
# Out:
# Empty DataFrame
# Columns: [Event_Time, Event_Date, Year, Month, Day, Hour, Minute, City, State, Shape, Duration, Summary, Event_URL]
# Index: []

# %%
#Compruebo si puedo aprovechar la columna Event_Time, para rellenar Hour 
df_ufo_nuforc[df_ufo_nuforc['Hour'].isnull()  & df_ufo_nuforc['Event_Time'].notnull()]
# Out:
# Empty DataFrame
# Columns: [Event_Time, Event_Date, Year, Month, Day, Hour, Minute, City, State, Shape, Duration, Summary, Event_URL]
# Index: []

# %%
#Compruebo si puedo aprovechar la columna Event_Time, para rellenar Minute
df_ufo_nuforc[df_ufo_nuforc['Minute'].isnull() & df_ufo_nuforc['Event_Time'].notnull()]
# Out:
# Empty DataFrame
# Columns: [Event_Time, Event_Date, Year, Month, Day, Hour, Minute, City, State, Shape, Duration, Summary, Event_URL]
# Index: []

# %%
#Compruebo si puedo aprovechar la columna Event_Time, para rellenar Year,Month,Day
df_ufo_nuforc[df_ufo_nuforc['Year'].isnull() & df_ufo_nuforc['Event_Time'].notnull()]
# Out:
# Empty DataFrame
# Columns: [Event_Time, Event_Date, Year, Month, Day, Hour, Minute, City, State, Shape, Duration, Summary, Event_URL]
# Index: []

# %%
#Compruebo si puedo aprovechar la columna Event_Time, para rellenar Year,Month,Day
df_ufo_nuforc[df_ufo_nuforc['Month'].isnull() & df_ufo_nuforc['Event_Time'].notnull()]
# Out:
# Empty DataFrame
# Columns: [Event_Time, Event_Date, Year, Month, Day, Hour, Minute, City, State, Shape, Duration, Summary, Event_URL]
# Index: []

# %%
#Compruebo si puedo aprovechar la columna Event_Time, para rellenar Year,Month,Day
df_ufo_nuforc[df_ufo_nuforc['Day'].isnull() & df_ufo_nuforc['Event_Time'].notnull()]
# Out:
# Empty DataFrame
# Columns: [Event_Time, Event_Date, Year, Month, Day, Hour, Minute, City, State, Shape, Duration, Summary, Event_URL]
# Index: []

# %%
# eliminar filas con Nan en columna 'Event_Date', son pocas en el total del dataframe unas 2000 para un df de unos 110000
# df_ufo_nuforc = df_ufo_nuforc.dropna(subset=['Event_Date'])
# df_ufo_nuforc
# NO LO HAGO no quiero perder info de las fechas, en vez de ello relleno missing hour y minute con 0 y 0
df_ufo_nuforc['Hour'].fillna(0.0, inplace=True)
df_ufo_nuforc['Minute'].fillna(0.0, inplace=True)

# %%
df_ufo_nuforc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110265 entries, 0 to 110264
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Event_Time  108575 non-null  object
#  1   Event_Date  110012 non-null  object
#  2   Year        110012 non-null  float64
#  3   Month       110012 non-null  float64
#  4   Day         110163 non-null  float64
#  5   Hour        110265 non-null  float64
#  6   Minute      110265 non-null  float64
#  7   City        110033 non-null  object
#  8   State       101961 non-null  object
#  9   Shape       106790 non-null  object
#  10  Duration    106103 non-null  object
#  11  Summary     110229 non-null  object
#  12  Event_URL   110265 non-null  object
# dtypes: float64(5), object(8)
# memory usage: 10.9+ MB

# %%
# limpiar filas por debajo año 1960, por tener baja ocurrencia

mask = df_ufo_nuforc['Year']<1961
df_ufo_nuforc = df_ufo_nuforc.drop(df_ufo_nuforc[mask].index)
df_ufo_nuforc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109449 entries, 0 to 110264
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Event_Time  107828 non-null  object
#  1   Event_Date  109196 non-null  object
#  2   Year        109196 non-null  float64
#  3   Month       109196 non-null  float64
#  4   Day         109347 non-null  float64
#  5   Hour        109449 non-null  float64
#  6   Minute      109449 non-null  float64
#  7   City        109222 non-null  object
#  8   State       101225 non-null  object
#  9   Shape       106023 non-null  object
#  10  Duration    105342 non-null  object
#  11  Summary     109415 non-null  object
#  12  Event_URL   109449 non-null  object
# dtypes: float64(5), object(8)
# memory usage: 11.7+ MB

# %%
# limpiar columnas event_time, info ya reflejada en date_time y su desglose
df_ufo_nuforc = df_ufo_nuforc.drop('Event_Time',axis=1)
df_ufo_nuforc
# Out:
#         Event_Date    Year  Month   Day  Hour  Minute        City State  \
# 0       2017-04-20  2017.0    4.0  20.0  14.0    15.0     Palmyra    NJ
# 1       2017-04-20  2017.0    4.0  20.0   4.0    56.0  Bridgeview    IL
# 2       2017-04-19  2017.0    4.0  19.0  23.0    55.0      Newton    AL
# 3       2017-04-19  2017.0    4.0  19.0  23.0    50.0      Newton    AL
# 4       2017-04-19  2017.0    4.0  19.0  23.0    29.0      Denver    CO
# ...            ...     ...    ...   ...   ...     ...         ...   ...
# 110260         NaN     NaN    NaN   NaN   0.0     0.0         NaN   NaN
# 110261         NaN     NaN    NaN   NaN   0.0     0.0        Rule    TX
# 110262         NaN     NaN    NaN   NaN   0.0     0.0    Subotica   NaN
# 110263         NaN     NaN    NaN   NaN   0.0     0.0    Key West    FL
# 110264         NaN     NaN    NaN   NaN   0.0     0.0    Richland    WA
#
#            Shape     Duration  \
# 0          Other    5 minutes
# 1          Light   20 seconds
# 2       Triangle    5 seconds
# 3       Triangle  5-6 minutes
# 4          Light       1 hour
# ...          ...          ...
# 110260  Cylinder          NaN
# 110261   Unknown   15 minutes
# 110262       NaN          NaN
# 110263     Other   one minute
# 110264    Sphere       10 min
#
#                                                   Summary  \
# 0         I observed an aircraft that seemed to look odd.
# 1       Bridgeview, IL, blue light.  ((anonymous report))
# 2                                    Silent triangle UFO.
# 3       My friend and I stepped outside hoping to catc...
# 4       Moved slow but made quick turns staying and ci...
# ...                                                   ...
# 110260  I video taped a UFO off the tv (cnn/headline n...
# 110261  Unusual sounds and starlight distortion defini...
# 110262  Objects was moving very fast on this about pos...
# 110263  I lived on a shallow-water marshland in Key We...
# 110264                                 Multiple sightings
#
#                                                 Event_URL
# 0       http://www.nuforc.org/webreports/133/S133726.html
# 1       http://www.nuforc.org/webreports/133/S133720.html
# 2       http://www.nuforc.org/webreports/133/S133724.html
# 3       http://www.nuforc.org/webreports/133/S133723.html
# 4       http://www.nuforc.org/webreports/133/S133721.html
# ...                                                   ...
# 110260   http://www.nuforc.org/webreports/032/S32416.html
# 110261   http://www.nuforc.org/webreports/091/S91521.html
# 110262   http://www.nuforc.org/webreports/086/S86594.html
# 110263   http://www.nuforc.org/webreports/034/S34436.html
# 110264   http://www.nuforc.org/webreports/087/S87806.html
#
# [109449 rows x 12 columns]

# %%
df_ufo_nuforc.info()
# ahora son 12 columnas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109449 entries, 0 to 110264
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Event_Date  109196 non-null  object
#  1   Year        109196 non-null  float64
#  2   Month       109196 non-null  float64
#  3   Day         109347 non-null  float64
#  4   Hour        109449 non-null  float64
#  5   Minute      109449 non-null  float64
#  6   City        109222 non-null  object
#  7   State       101225 non-null  object
#  8   Shape       106023 non-null  object
#  9   Duration    105342 non-null  object
#  10  Summary     109415 non-null  object
#  11  Event_URL   109449 non-null  object
# dtypes: float64(5), object(7)
# memory usage: 10.9+ MB

# %%
# eliminar filas con Nan en columna 'Year' and 'Month', son pocas en el total del dataframe,
#   y asi puedo forzar en el ssgte paso a convertir a int, ya que los nan no los cambia da error
df_ufo_nuforc_1 = df_ufo_nuforc.dropna(subset=['Year','Month']).copy()
df_ufo_nuforc_1
# Out:
#         Event_Date    Year  Month   Day  Hour  Minute                    City  \
# 0       2017-04-20  2017.0    4.0  20.0  14.0    15.0                 Palmyra
# 1       2017-04-20  2017.0    4.0  20.0   4.0    56.0              Bridgeview
# 2       2017-04-19  2017.0    4.0  19.0  23.0    55.0                  Newton
# 3       2017-04-19  2017.0    4.0  19.0  23.0    50.0                  Newton
# 4       2017-04-19  2017.0    4.0  19.0  23.0    29.0                  Denver
# ...            ...     ...    ...   ...   ...     ...                     ...
# 109191  1961-03-01  1961.0    3.0   1.0   0.0     0.0  Bracknell (UK/England)
# 109192  1961-02-22  1961.0    2.0  22.0  20.0     0.0               Panhandle
# 109193  1961-02-02  1961.0    2.0   2.0   1.0     0.0               Lancaster
# 109194  1961-01-01  1961.0    1.0   1.0  13.0     0.0            Kendallville
# 109195  1961-01-01  1961.0    1.0   1.0  12.0     0.0             Santa Clara
#
#        State     Shape     Duration  \
# 0         NJ     Other    5 minutes
# 1         IL     Light   20 seconds
# 2         AL  Triangle    5 seconds
# 3         AL  Triangle  5-6 minutes
# 4         CO     Light       1 hour
# ...      ...       ...          ...
# 109191   NaN      Disk            ?
# 109192    TX   Diamond     ~2 hours
# 109193    CA      Disk       3 Min.
# 109194    IN    Circle   30 seconds
# 109195    CA    Circle      3 hours
#
#                                                   Summary  \
# 0         I observed an aircraft that seemed to look odd.
# 1       Bridgeview, IL, blue light.  ((anonymous report))
# 2                                    Silent triangle UFO.
# 3       My friend and I stepped outside hoping to catc...
# 4       Moved slow but made quick turns staying and ci...
# ...                                                   ...
# 109191  I was born in Bracknell UK 1961.  I had an exp...
# 109192                          Texas Panhandle Nuke site
# 109193  Brilliant,silver disk. 50 to 55 degree angle o...
# 109194  It was a clear Indiana day and I saw something...
# 109195         Stationary circular object 12 oclock high.
#
#                                                 Event_URL
# 0       http://www.nuforc.org/webreports/133/S133726.html
# 1       http://www.nuforc.org/webreports/133/S133720.html
# 2       http://www.nuforc.org/webreports/133/S133724.html
# 3       http://www.nuforc.org/webreports/133/S133723.html
# 4       http://www.nuforc.org/webreports/133/S133721.html
# ...                                                   ...
# 109191  http://www.nuforc.org/webreports/119/S119064.html
# 109192   http://www.nuforc.org/webreports/031/S31470.html
# 109193   http://www.nuforc.org/webreports/005/S05742.html
# 109194   http://www.nuforc.org/webreports/058/S58389.html
# 109195   http://www.nuforc.org/webreports/034/S34475.html
#
# [109196 rows x 12 columns]

# %%
df_ufo_nuforc_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109196 entries, 0 to 109195
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Event_Date  109196 non-null  object
#  1   Year        109196 non-null  float64
#  2   Month       109196 non-null  float64
#  3   Day         109196 non-null  float64
#  4   Hour        109196 non-null  float64
#  5   Minute      109196 non-null  float64
#  6   City        108980 non-null  object
#  7   State       101025 non-null  object
#  8   Shape       105796 non-null  object
#  9   Duration    105134 non-null  object
#  10  Summary     109162 non-null  object
#  11  Event_URL   109196 non-null  object
# dtypes: float64(5), object(7)
# memory usage: 10.8+ MB

# %%
df_ufo_nuforc_7 = df_ufo_nuforc_1.copy()
# convertimos las columnas siguientes a int
df_ufo_nuforc_7['Year'] = df_ufo_nuforc_7['Year'].astype(int)
df_ufo_nuforc_7['Month'] = df_ufo_nuforc_7['Month'].astype(int)
df_ufo_nuforc_7['Day'] = df_ufo_nuforc_7['Day'].astype(int)
df_ufo_nuforc_7['Hour'] = df_ufo_nuforc_7['Hour'].astype(int)
df_ufo_nuforc_7['Minute'] = df_ufo_nuforc_7['Minute'].astype(int)

df_ufo_nuforc_7
# Out:
#         Event_Date  Year  Month  Day  Hour  Minute                    City  \
# 0       2017-04-20  2017      4   20    14      15                 Palmyra
# 1       2017-04-20  2017      4   20     4      56              Bridgeview
# 2       2017-04-19  2017      4   19    23      55                  Newton
# 3       2017-04-19  2017      4   19    23      50                  Newton
# 4       2017-04-19  2017      4   19    23      29                  Denver
# ...            ...   ...    ...  ...   ...     ...                     ...
# 109191  1961-03-01  1961      3    1     0       0  Bracknell (UK/England)
# 109192  1961-02-22  1961      2   22    20       0               Panhandle
# 109193  1961-02-02  1961      2    2     1       0               Lancaster
# 109194  1961-01-01  1961      1    1    13       0            Kendallville
# 109195  1961-01-01  1961      1    1    12       0             Santa Clara
#
#        State     Shape     Duration  \
# 0         NJ     Other    5 minutes
# 1         IL     Light   20 seconds
# 2         AL  Triangle    5 seconds
# 3         AL  Triangle  5-6 minutes
# 4         CO     Light       1 hour
# ...      ...       ...          ...
# 109191   NaN      Disk            ?
# 109192    TX   Diamond     ~2 hours
# 109193    CA      Disk       3 Min.
# 109194    IN    Circle   30 seconds
# 109195    CA    Circle      3 hours
#
#                                                   Summary  \
# 0         I observed an aircraft that seemed to look odd.
# 1       Bridgeview, IL, blue light.  ((anonymous report))
# 2                                    Silent triangle UFO.
# 3       My friend and I stepped outside hoping to catc...
# 4       Moved slow but made quick turns staying and ci...
# ...                                                   ...
# 109191  I was born in Bracknell UK 1961.  I had an exp...
# 109192                          Texas Panhandle Nuke site
# 109193  Brilliant,silver disk. 50 to 55 degree angle o...
# 109194  It was a clear Indiana day and I saw something...
# 109195         Stationary circular object 12 oclock high.
#
#                                                 Event_URL
# 0       http://www.nuforc.org/webreports/133/S133726.html
# 1       http://www.nuforc.org/webreports/133/S133720.html
# 2       http://www.nuforc.org/webreports/133/S133724.html
# 3       http://www.nuforc.org/webreports/133/S133723.html
# 4       http://www.nuforc.org/webreports/133/S133721.html
# ...                                                   ...
# 109191  http://www.nuforc.org/webreports/119/S119064.html
# 109192   http://www.nuforc.org/webreports/031/S31470.html
# 109193   http://www.nuforc.org/webreports/005/S05742.html
# 109194   http://www.nuforc.org/webreports/058/S58389.html
# 109195   http://www.nuforc.org/webreports/034/S34475.html
#
# [109196 rows x 12 columns]

# %%
df_ufo_nuforc_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109196 entries, 0 to 109195
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Event_Date  109196 non-null  object
#  1   Year        109196 non-null  int32
#  2   Month       109196 non-null  int32
#  3   Day         109196 non-null  int32
#  4   Hour        109196 non-null  int32
#  5   Minute      109196 non-null  int32
#  6   City        108980 non-null  object
#  7   State       101025 non-null  object
#  8   Shape       105796 non-null  object
#  9   Duration    105134 non-null  object
#  10  Summary     109162 non-null  object
#  11  Event_URL   109196 non-null  object
# dtypes: int32(5), object(7)
# memory usage: 8.7+ MB

# %%
df_ufo_nuforc_3 = df_ufo_nuforc_7.copy()
mask = df_ufo_nuforc_3['State'].isna() # mascara booleana de los nan de la columna state

# Saca el contenido entre paréntesis en la columna 'City' y se lo asigna a la columna State que estaba en nan
df_ufo_nuforc_3.loc[mask, 'State'] = df_ufo_nuforc_3.loc[mask, 'City'].str.extract('\((.*?)\)', expand=False)#la expr busca coinc, expand 1 coinc sin df con todas

# Eliminar los paréntesis de la columna 'City' para que quede con el texto sin paréntesis
df_ufo_nuforc_3['City'] = df_ufo_nuforc_3['City'].str.replace('\(.*\)', '', regex=True) #la exp  regex en este metodo str dice q la exp es reg

# %%
df_ufo_nuforc_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109196 entries, 0 to 109195
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Event_Date  109196 non-null  object
#  1   Year        109196 non-null  int32
#  2   Month       109196 non-null  int32
#  3   Day         109196 non-null  int32
#  4   Hour        109196 non-null  int32
#  5   Minute      109196 non-null  int32
#  6   City        108980 non-null  object
#  7   State       108366 non-null  object
#  8   Shape       105796 non-null  object
#  9   Duration    105134 non-null  object
#  10  Summary     109162 non-null  object
#  11  Event_URL   109196 non-null  object
# dtypes: int32(5), object(7)
# memory usage: 8.7+ MB

# %%
df_ufo_nuforc_3.head(10)
# Out:
#    Event_Date  Year  Month  Day  Hour  Minute                City  State  \
# 0  2017-04-20  2017      4   20    14      15             Palmyra     NJ
# 1  2017-04-20  2017      4   20     4      56          Bridgeview     IL
# 2  2017-04-19  2017      4   19    23      55              Newton     AL
# 3  2017-04-19  2017      4   19    23      50              Newton     AL
# 4  2017-04-19  2017      4   19    23      29              Denver     CO
# 5  2017-04-19  2017      4   19    21      45            Cobourg      ON
# 6  2017-04-19  2017      4   19    20      50         Garden City     SC
# 7  2017-04-19  2017      4   19    20      50  North Myrtle Beach     SC
# 8  2017-04-19  2017      4   19    20      30      Surfside Beach     SC
# 9  2017-04-19  2017      4   19    20      10         Chiba City   Japan
#
#       Shape     Duration                                            Summary  \
# 0     Other    5 minutes    I observed an aircraft that seemed to look odd.
# 1     Light   20 seconds  Bridgeview, IL, blue light.  ((anonymous report))
# 2  Triangle    5 seconds                               Silent triangle UFO.
# 3  Triangle  5-6 minutes  My friend and I stepped outside hoping to catc...
# 4     Light       1 hour  Moved slow but made quick turns staying and ci...
# 5     Light    4 minutes  Two "satellites" traving S in tandem, then re...
# 6    Sphere   20 seconds  Five bright orange orbs appear quietly over wa...
# 7     Light     1 minute  Orange Orbs Spotted Over North Myrtle Beach......
# 8    Circle   15 seconds  Single orb over ocean, moved north, 5 orbs for...
# 9   Unknown    3 seconds  I saw a fast pretty round object from the othe...
#
#                                            Event_URL
# 0  http://www.nuforc.org/webreports/133/S133726.html
# 1  http://www.nuforc.org/webreports/133/S133720.html
# 2  http://www.nuforc.org/webreports/133/S133724.html
# 3  http://www.nuforc.org/webreports/133/S133723.html
# 4  http://www.nuforc.org/webreports/133/S133721.html
# 5  http://www.nuforc.org/webreports/133/S133715.html
# 6  http://www.nuforc.org/webreports/133/S133718.html
# 7  http://www.nuforc.org/webreports/133/S133716.html
# 8  http://www.nuforc.org/webreports/133/S133713.html
# 9  http://www.nuforc.org/webreports/133/S133703.html

# %%
estados_fuera_parentesis = df_ufo_nuforc_3.copy()

# %%
estados_fuera_parentesis[estados_fuera_parentesis['State'].isnull() & estados_fuera_parentesis['City'].notnull()]
#lineas que aun tienen State nan y tienen ciudad
# Out:
#         Event_Date  Year  Month  Day  Hour  Minute                    City  \
# 94      2017-04-13  2017      4   13    16      30                   Mckee
# 197     2017-04-05  2017      4    5    23       0  Greater Atlanta- south
# 552     2017-03-02  2017      3    2    11      20                 Burbank
# 684     2017-02-20  2017      2   20    12      45                Hiwassee
# 910     2017-02-05  2017      2    5    23      23                Puyallup
# ...            ...   ...    ...  ...   ...     ...                     ...
# 108774  1965-06-19  1965      6   19     0       0         Western Pacific
# 108833  1965-04-01  1965      4    1    15       0            West Germany
# 109000  1963-06-30  1963      6   30    15       0                  Canada
# 109067  1962-09-15  1962      9   15     7       0             Puerto Rico
# 109186  1961-05-04  1961      5    4     1       0    South Pacific Island
#
#        State     Shape         Duration  \
# 94       NaN       NaN         1 minute
# 197      NaN     Other       10 minutes
# 552      NaN    Sphere         00:00:10
# 684      NaN       Egg       15 seconds
# 910      NaN       NaN      3-5 seconds
# ...      ...       ...              ...
# 108774   NaN   Unknown      1-2 minutes
# 108833   NaN      Disk           8 sec.
# 109000   NaN  Triangle  less than 1 min
# 109067   NaN      Disk  Hour and a Half
# 109186   NaN   Unknown   01:00 to 03:00
#
#                                                   Summary  \
# 94      Object seen twice moving low in Jackson County...
# 197     Your rules for reporting are ridiculous. Most ...
# 552     A silvery orb high up to the ENE.  Appeared to...
# 684     Fast white hazy object larger than jet incredi...
# 910                     2 Bright Blue Flashes with sound.
# ...                                                   ...
# 108774  high speed ufo spotted and tracked on U.S. Nav...
# 108833  Saucer with lights, did not appear to be movin...
# 109000   Silent black triangle flew over our car in 1963.
# 109067   Spinning lights inside of a small boiling cloud.
# 109186  Peculiar object seen on military radar over th...
#
#                                                 Event_URL
# 94      http://www.nuforc.org/webreports/133/S133616.html
# 197     http://www.nuforc.org/webreports/133/S133455.html
# 552     http://www.nuforc.org/webreports/132/S132794.html
# 684     http://www.nuforc.org/webreports/132/S132732.html
# 910     http://www.nuforc.org/webreports/132/S132484.html
# ...                                                   ...
# 108774   http://www.nuforc.org/webreports/043/S43396.html
# 108833   http://www.nuforc.org/webreports/056/S56836.html
# 109000  http://www.nuforc.org/webreports/107/S107526.html
# 109067   http://www.nuforc.org/webreports/067/S67756.html
# 109186   http://www.nuforc.org/webreports/073/S73370.html
#
# [715 rows x 12 columns]

# %%
'''NO ME DA TIEMPO PERO LO SUYO SERIA PASAR CITY A STATE, ALGUNOS SON ESTADOS DEL MUNDO OTRO SON CIUDADES(USA), 
PARA LAS CIUDADES PODRIA BUSCAR EL ESTADO CORRESPONDINETE'''
# Out:
# 'NO ME DA TIEMPO PERO LO SUYO SERIA PASAR CITY A STATE, ALGUNOS SON ESTADOS DEL MUNDO OTRO SON CIUDADES(USA), \nPARA LAS CIUDADES PODRIA BUSCAR EL ESTADO CORRESPONDINETE'

# %%
# elimino las filas que tengan state a nan
df_ufo_nuforc_4 = estados_fuera_parentesis.dropna(subset=['State'])
df_ufo_nuforc_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108366 entries, 0 to 109195
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Event_Date  108366 non-null  object
#  1   Year        108366 non-null  int32
#  2   Month       108366 non-null  int32
#  3   Day         108366 non-null  int32
#  4   Hour        108366 non-null  int32
#  5   Minute      108366 non-null  int32
#  6   City        108265 non-null  object
#  7   State       108366 non-null  object
#  8   Shape       105111 non-null  object
#  9   Duration    104451 non-null  object
#  10  Summary     108332 non-null  object
#  11  Event_URL   108366 non-null  object
# dtypes: int32(5), object(7)
# memory usage: 8.7+ MB

# %%
'''ojoooooooooooooo ciudades y (SHAPE,DURATION Y sumarios....estos me dan igual), se van quedando por detras con los nan 
ya vere que hago
'''
# Out:
# 'ojoooooooooooooo ciudades y (SHAPE,DURATION Y sumarios....estos me dan igual), se van quedando por detras con los nan \nya vere que hago\n'

# %%
# relleno las ciudades nan con '', para no perder fecha ni estado, son pocas 99 lineas q mantengo
df_ufo_nuforc_7 =df_ufo_nuforc_4.copy()
df_ufo_nuforc_7['City'].fillna('', inplace=True)
df_ufo_nuforc_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108366 entries, 0 to 109195
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Event_Date  108366 non-null  object
#  1   Year        108366 non-null  int32
#  2   Month       108366 non-null  int32
#  3   Day         108366 non-null  int32
#  4   Hour        108366 non-null  int32
#  5   Minute      108366 non-null  int32
#  6   City        108366 non-null  object
#  7   State       108366 non-null  object
#  8   Shape       105111 non-null  object
#  9   Duration    104451 non-null  object
#  10  Summary     108332 non-null  object
#  11  Event_URL   108366 non-null  object
# dtypes: int32(5), object(7)
# memory usage: 8.7+ MB

# %%
#NO VOY A RELLENAR NI SHAPE NI DURATION no los voy a utilizar, ya esta
# df_ufo_nuforc_6 = df_ufo_nuforc_4.copy()
# df_ufo_nuforc_6['Shape'].fillna('', inplace=True)
# df_ufo_nuforc_6['Duration'].fillna('', inplace=True)
# df_ufo_nuforc_6.info()

# %%
# PRUEBA NO VA A MEMORIA.........................

# Cuenta los avistamientos por año
avistamientos_por_año = df_ufo_nuforc_7['Year'].value_counts()

# Ordena los resultados por año en orden ascendente
avistamientos_por_año = avistamientos_por_año.sort_index()

# Muestra el número de avistamientos por año
print(avistamientos_por_año)
# df_avistamientos_por_año = pd.DataFrame({'Año': avistamientos_por_año.index, 'Avistamientos': avistamientos_por_año.values})
# df_avistamientos_por_año
# Out:
# Year
# 1961      57
# 1962      82
# 1963      94
# 1964     115
# 1965     215
# 1966     237
# 1967     236
# 1968     265
# 1969     186
# 1970     181
# 1971     139
# 1972     204
# 1973     268
# 1974     312
# 1975     372
# 1976     333
# 1977     315
# 1978     389
# 1979     291
# 1980     289
# 1981     204
# 1982     218
# 1983     191
# 1984     213
# 1985     252
# 1986     224
# 1987     270
# 1988     280
# 1989     293
# 1990     304
# 1991     275
# 1992     301
# 1993     377
# 1994     490
# 1995    1460
# 1996     994
# 1997    1428
# 1998    2001
# 1999    3131
# 2000    3060
# 2001    3497
# 2002    3636
# 2003    4382
# 2004    4674
# 2005    4467
# 2006    4099
# 2007    4681
# 2008    5231
# 2009    4927
# 2010    4717
# 2011    5550
# 2012    8024
# 2013    7737
# 2014    8589
# 2015    6809
# 2016    5525
# 2017    1275
# Name: count, dtype: int64

# %%
# ESTRENO STAR TREK TV 8/9/1966 TELEVISION
df_ufo_nuforc_7['Event_Date'] = pd.to_datetime(df_ufo_nuforc_7['Event_Date'])#convertimos a objeto datetime

# Filtra los registros para el año 1966
df_1966 = df_ufo_nuforc_7[df_ufo_nuforc_7['Event_Date'].dt.year == 1966]

# Cuenta los avistamientos para cada día
avistamientos_por_fecha_66 = df_1966['Event_Date'].dt.date.value_counts()

# Ordena los resultados por la cantidad de avistamientos en orden descendente
avistamientos_por_fecha_66 = avistamientos_por_fecha_66.sort_values(ascending=False)

# Muestra las fechas con la mayor cantidad de avistamientos (por ejemplo, las 20 primeras)
top_fechas_avistamientos_66 = avistamientos_por_fecha_66.head(20)
print(top_fechas_avistamientos_66)
# Out:
# Event_Date
# 1966-06-01    26
# 1966-06-15    19
# 1966-06-30    18
# 1966-07-01     8
# 1966-09-15     8
# 1966-07-15     7
# 1966-03-15     6
# 1966-10-15     6
# 1966-11-01     5
# 1966-10-01     5
# 1966-05-15     4
# 1966-08-15     4
# 1966-04-01     4
# 1966-05-01     3
# 1966-08-01     3
# 1966-06-06     3
# 1966-06-25     3
# 1966-06-12     3
# 1966-12-15     3
# 1966-04-15     3
# Name: count, dtype: int64

# %%
# Agrupa los avistamientos por mes y suma la cantidad
avistamientos_por_mes_66 = df_1966.groupby(df_1966['Event_Date'].dt.month)['Event_Date'].count()

# Ordena los resultados por mes
avistamientos_por_mes_66 = avistamientos_por_mes_66.sort_index()

# Crea el gráfico de barras
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
plt.figure(figsize=(10, 6))
plt.bar(meses, avistamientos_por_mes_66, color='skyblue')
plt.xlabel('Mes')
plt.ylabel('Cantidad de Avistamientos')
plt.title('ESTRENO STAR TREK TV 8/9/1966 Avistamientos Mensuales/66')

# Muestra el gráfico de barras
plt.xticks(rotation=45)
plt.show()

# %%
# STAR WARS IV Estreno 25/5/77

df_ufo_nuforc_7['Event_Date'] = pd.to_datetime(df_ufo_nuforc_7['Event_Date'])#convertimos a objeto datetime

# Filtra los registros para el año 1977
df_1977 = df_ufo_nuforc_7[df_ufo_nuforc_7['Event_Date'].dt.year == 1977]

# Cuenta los avistamientos para cada día
avistamientos_por_fecha_77 = df_1977['Event_Date'].dt.date.value_counts()

# Ordena los resultados por la cantidad de avistamientos en orden descendente
avistamientos_por_fecha_77 = avistamientos_por_fecha_77.sort_values(ascending=False)

# Muestra las fechas con la mayor cantidad de avistamientos (por ejemplo, las 20 primeras)
top_fechas_avistamientos_77 = avistamientos_por_fecha_77.head(20)
print(top_fechas_avistamientos_77)
# Out:
# Event_Date
# 1977-06-01    24
# 1977-06-15    24
# 1977-07-15    18
# 1977-09-01    11
# 1977-05-01    10
# 1977-06-30     9
# 1977-07-01     9
# 1977-09-15     8
# 1977-08-15     8
# 1977-08-01     7
# 1977-01-01     5
# 1977-06-10     5
# 1977-07-20     4
# 1977-05-15     4
# 1977-08-08     4
# 1977-07-26     4
# 1977-07-02     4
# 1977-07-04     4
# 1977-04-15     4
# 1977-10-15     4
# Name: count, dtype: int64

# %%
# Agrupa los avistamientos por mes y suma la cantidad
avistamientos_por_mes_77 = df_1977.groupby(df_1977['Event_Date'].dt.month)['Event_Date'].count()

# Ordena los resultados por mes
avistamientos_por_mes_77 = avistamientos_por_mes_77.sort_index()

# Crea el gráfico de barras
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
plt.figure(figsize=(10, 6))
plt.bar(meses, avistamientos_por_mes_77, color='skyblue')
plt.xlabel('Mes')
plt.ylabel('Cantidad de Avistamientos')
plt.title('Estreno Star Wars IV(25/5/77) Avistamientos Mensuales/77')

# Muestra el gráfico de barras
plt.xticks(rotation=45)
plt.show()

# %%
# Encuentros en la III fase Estreno 17/3/78

df_ufo_nuforc_7['Event_Date'] = pd.to_datetime(df_ufo_nuforc_7['Event_Date'])#convertimos a objeto datetime

# Filtra los registros para el año 1978
df_1978 = df_ufo_nuforc_7[df_ufo_nuforc_7['Event_Date'].dt.year == 1978]

# Cuenta los avistamientos para cada día
avistamientos_por_fecha_78 = df_1978['Event_Date'].dt.date.value_counts()

# Ordena los resultados por la cantidad de avistamientos en orden descendente
avistamientos_por_fecha_78 = avistamientos_por_fecha_78.sort_values(ascending=False)

# Muestra las fechas con la mayor cantidad de avistamientos (por ejemplo, las 20 primeras)
top_fechas_avistamientos = avistamientos_por_fecha_78.head(20)
print(top_fechas_avistamientos)
# Out:
# Event_Date
# 1978-06-01    30
# 1978-06-15    22
# 1978-06-30    21
# 1978-08-15    20
# 1978-07-01    19
# 1978-07-15    16
# 1978-10-15     9
# 1978-08-01     9
# 1978-09-15     9
# 1978-07-04     9
# 1978-09-01     6
# 1978-07-20     6
# 1978-11-01     5
# 1978-01-01     5
# 1978-07-26     5
# 1978-04-04     4
# 1978-02-15     4
# 1978-07-07     4
# 1978-07-22     4
# 1978-10-12     3
# Name: count, dtype: int64

# %%
# Agrupa los avistamientos por mes y suma la cantidad
avistamientos_por_mes_78 = df_1978.groupby(df_1978['Event_Date'].dt.month)['Event_Date'].count()

# Ordena los resultados por mes
avistamientos_por_mes_78 = avistamientos_por_mes_78.sort_index()

# Crea el gráfico de barras
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
plt.figure(figsize=(10, 6))
plt.bar(meses, avistamientos_por_mes_78, color='skyblue')
plt.xlabel('Mes')
plt.ylabel('Cantidad de Avistamientos')
plt.title('Encuentros en la III fase(17/3/78) Avistamientos Mensuales/78')

# Muestra el gráfico de barras
plt.xticks(rotation=45)
plt.show()

# %%
# STAR TREK Estreno EN CINE 7/12/79

df_ufo_nuforc_7['Event_Date'] = pd.to_datetime(df_ufo_nuforc_7['Event_Date'])#convertimos a objeto datetime

# Filtra los registros para el año 1979
df_1979 = df_ufo_nuforc_7[df_ufo_nuforc_7['Event_Date'].dt.year == 1979]

# Cuenta los avistamientos para cada día
avistamientos_por_fecha_79 = df_1979['Event_Date'].dt.date.value_counts()

# Ordena los resultados por la cantidad de avistamientos en orden descendente
avistamientos_por_fecha_79 = avistamientos_por_fecha_79.sort_values(ascending=False)

# Muestra las fechas con la mayor cantidad de avistamientos (por ejemplo, las 20 primeras)
top_fechas_avistamientos_79 = avistamientos_por_fecha_79.head(20)
print(top_fechas_avistamientos_79)
# Out:
# Event_Date
# 1979-06-01    31
# 1979-07-15    17
# 1979-06-15    17
# 1979-09-01    12
# 1979-06-30    12
# 1979-07-01    11
# 1979-08-15     9
# 1979-08-01     8
# 1979-10-01     8
# 1979-05-15     6
# 1979-04-15     5
# 1979-01-01     4
# 1979-06-20     4
# 1979-10-10     4
# 1979-01-15     3
# 1979-11-10     3
# 1979-04-01     3
# 1979-11-15     3
# 1979-09-15     3
# 1979-11-01     3
# Name: count, dtype: int64

# %%
# Agrupa los avistamientos por mes y suma la cantidad
avistamientos_por_mes_79 = df_1979.groupby(df_1979['Event_Date'].dt.month)['Event_Date'].count()

# Ordena los resultados por mes
avistamientos_por_mes_79 = avistamientos_por_mes_79.sort_index()

# Crea el gráfico de barras
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
plt.figure(figsize=(10, 6))
plt.bar(meses, avistamientos_por_mes_79, color='skyblue')
plt.xlabel('Mes')
plt.ylabel('Cantidad de Avistamientos')
plt.title('STAR TREK The Movie(7/12/79) Avistamientos Mensuales/79')

# Muestra el gráfico de barras
plt.xticks(rotation=45)
plt.show()

# %%
# INDEPENDENCE DAY 6/7/1996 Estreno EN CINE 

df_ufo_nuforc_7['Event_Date'] = pd.to_datetime(df_ufo_nuforc_7['Event_Date'])#convertimos a objeto datetime

# Filtra los registros para el año 1996
df_1996 = df_ufo_nuforc_7[df_ufo_nuforc_7['Event_Date'].dt.year == 1996]

# Cuenta los avistamientos para cada día
avistamientos_por_fecha_96 = df_1996['Event_Date'].dt.date.value_counts()

# Ordena los resultados por la cantidad de avistamientos en orden descendente
avistamientos_por_fecha_96 = avistamientos_por_fecha_96.sort_values(ascending=False)

# Muestra las fechas con la mayor cantidad de avistamientos (por ejemplo, las 20 primeras)
top_fechas_avistamientos_96 = avistamientos_por_fecha_96.head(20)
print(top_fechas_avistamientos_96)
# Out:
# Event_Date
# 1996-06-01    37
# 1996-06-15    30
# 1996-08-15    20
# 1996-08-01    18
# 1996-07-15    17
# 1996-11-16    17
# 1996-07-01    16
# 1996-04-15    14
# 1996-12-17    13
# 1996-06-30    12
# 1996-09-15    12
# 1996-04-14    11
# 1996-04-01    10
# 1996-09-01    10
# 1996-02-09    10
# 1996-06-20    10
# 1996-05-01     9
# 1996-03-01     9
# 1996-06-12     8
# 1996-11-30     8
# Name: count, dtype: int64

# %%
# Agrupa los avistamientos por mes y suma la cantidad
avistamientos_por_mes_96 = df_1996.groupby(df_1996['Event_Date'].dt.month)['Event_Date'].count()

# Ordena los resultados por mes
avistamientos_por_mes_96 = avistamientos_por_mes_96.sort_index()

# Crea el gráfico de barras
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
plt.figure(figsize=(10, 6))
plt.bar(meses, avistamientos_por_mes_96, color='skyblue')
plt.xlabel('Mes')
plt.ylabel('Cantidad de Avistamientos')
plt.title('INDEPENDENCE DAY 6/7/1996(Estreno) Avistamientos Mensuales/96')

# Muestra el gráfico de barras
plt.xticks(rotation=45)
plt.show()

# %%
# STAR WARS EPISODIO I AMENAZA FANTASMA 19/5/1999 Estreno EN CINE 

df_ufo_nuforc_7['Event_Date'] = pd.to_datetime(df_ufo_nuforc_7['Event_Date'])#convertimos a objeto datetime

# Filtra los registros para el año 1996
df_1999 = df_ufo_nuforc_7[df_ufo_nuforc_7['Event_Date'].dt.year == 1999]

# Cuenta los avistamientos para cada día
avistamientos_por_fecha_99 = df_1999['Event_Date'].dt.date.value_counts()

# Ordena los resultados por la cantidad de avistamientos en orden descendente
avistamientos_por_fecha_99 = avistamientos_por_fecha_99.sort_values(ascending=False)

# Muestra las fechas con la mayor cantidad de avistamientos (por ejemplo, las 20 primeras)
top_fechas_avistamientos_99 = avistamientos_por_fecha_99.head(20)
print(top_fechas_avistamientos_99)
# Out:
# Event_Date
# 1999-11-16    195
# 1999-09-01     70
# 1999-08-15     54
# 1999-06-01     49
# 1999-06-15     35
# 1999-10-15     31
# 1999-09-07     30
# 1999-09-11     29
# 1999-07-01     24
# 1999-09-15     23
# 1999-07-15     22
# 1999-08-12     22
# 1999-10-26     22
# 1999-08-01     21
# 1999-12-26     19
# 1999-09-05     19
# 1999-10-11     19
# 1999-03-04     19
# 1999-07-04     18
# 1999-07-18     17
# Name: count, dtype: int64

# %%
# Agrupa los avistamientos por mes y suma la cantidad
avistamientos_por_mes_99 = df_1999.groupby(df_1999['Event_Date'].dt.month)['Event_Date'].count()

# Ordena los resultados por mes
avistamientos_por_mes_99 = avistamientos_por_mes_99.sort_index()

# Crea el gráfico de barras
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
plt.figure(figsize=(10, 6))
plt.bar(meses, avistamientos_por_mes_99, color='skyblue')
plt.xlabel('Mes')
plt.ylabel('Cantidad de Avistamientos')
plt.title('STAR WARS EPISODIO I AMENAZA FANTASMA Estreno(19/5/1999) Avistamientos Mensuales/99')

# Muestra el gráfico de barras
plt.xticks(rotation=45)
plt.show()

# %%
# HACIENDO MAS PEQUEÑO EL DATAFRAME
mask = df_ufo_nuforc_7['Year']<1999
nuforc_99_17 = df_ufo_nuforc_7.drop(df_ufo_nuforc_7[mask].index)
nuforc_99_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94011 entries, 0 to 94682
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Event_Date  94011 non-null  datetime64[ns]
#  1   Year        94011 non-null  int32
#  2   Month       94011 non-null  int32
#  3   Day         94011 non-null  int32
#  4   Hour        94011 non-null  int32
#  5   Minute      94011 non-null  int32
#  6   City        94011 non-null  object
#  7   State       94011 non-null  object
#  8   Shape       92223 non-null  object
#  9   Duration    90855 non-null  object
#  10  Summary     93992 non-null  object
#  11  Event_URL   94011 non-null  object
# dtypes: datetime64[ns](1), int32(5), object(6)
# memory usage: 7.5+ MB

# %%
nuforc_99_17
# Out:
#       Event_Date  Year  Month  Day  Hour  Minute                    City  \
# 0     2017-04-20  2017      4   20    14      15                 Palmyra
# 1     2017-04-20  2017      4   20     4      56              Bridgeview
# 2     2017-04-19  2017      4   19    23      55                  Newton
# 3     2017-04-19  2017      4   19    23      50                  Newton
# 4     2017-04-19  2017      4   19    23      29                  Denver
# ...          ...   ...    ...  ...   ...     ...                     ...
# 94678 1999-01-01  1999      1    1    14       0                Florence
# 94679 1999-01-01  1999      1    1     3      54               Auckland
# 94680 1999-01-01  1999      1    1     3       0                 Bauxite
# 94681 1999-01-01  1999      1    1     2      30               Loma Rica
# 94682 1999-01-01  1999      1    1     1      35  Puerto Ordaz, Bolivar
#
#              State     Shape      Duration  \
# 0               NJ     Other     5 minutes
# 1               IL     Light    20 seconds
# 2               AL  Triangle     5 seconds
# 3               AL  Triangle   5-6 minutes
# 4               CO     Light        1 hour
# ...            ...       ...           ...
# 94678           SC  Cylinder       10 min.
# 94679  New Zealand      Disk     5 minutes
# 94680           AR       NaN     2 minutes
# 94681           CA     Light  10-20minutes
# 94682    Venezuela     Light         3 min
#
#                                                  Summary  \
# 0        I observed an aircraft that seemed to look odd.
# 1      Bridgeview, IL, blue light.  ((anonymous report))
# 2                                   Silent triangle UFO.
# 3      My friend and I stepped outside hoping to catc...
# 4      Moved slow but made quick turns staying and ci...
# ...                                                  ...
# 94678  It was a clear day  when I saw a  silver cylin...
# 94679  me and my sister witness ufo in a field, we go...
# 94680                                    Close encounter
# 94681                 Lights I saw and now seem to feel.
# 94682  It was a ligth in a rounded shape, hight speed...
#
#                                                Event_URL
# 0      http://www.nuforc.org/webreports/133/S133726.html
# 1      http://www.nuforc.org/webreports/133/S133720.html
# 2      http://www.nuforc.org/webreports/133/S133724.html
# 3      http://www.nuforc.org/webreports/133/S133723.html
# 4      http://www.nuforc.org/webreports/133/S133721.html
# ...                                                  ...
# 94678   http://www.nuforc.org/webreports/030/S30662.html
# 94679   http://www.nuforc.org/webreports/013/S13413.html
# 94680   http://www.nuforc.org/webreports/079/S79722.html
# 94681   http://www.nuforc.org/webreports/043/S43863.html
# 94682   http://www.nuforc.org/webreports/005/S05288.html
#
# [94011 rows x 12 columns]

# %%
# pd.set_option('display.max_rows', 500)

# nuforc_10_17_1 = nuforc_10_17.drop_duplicates(subset=['Event_Date', 'City'])'''lo que ocurra en el mismo dia y en el mismo lugar, 
#                                                                             se pierden horas diferentes NO LO HAGO'''
# nuforc_10_17_1

# %%
# HIPOTESIS CONCENTRACION EN FECHAS ESPECIALES


nuforc_99_17['Event_Date'] = pd.to_datetime(nuforc_99_17['Event_Date'])

# Utiliza el método "value_counts" para contar las ocurrencias de cada fecha
date_counts = nuforc_99_17['Event_Date'].value_counts()

# Ordena las fechas por la cantidad de ocurrencias en orden descendente
date_counts = date_counts.sort_values(ascending=False)

# Muestra las fechas que más se repiten
print(date_counts.head(20))
# Out:
# Event_Date
# 2015-11-07    289
# 2014-07-04    268
# 2010-07-04    210
# 1999-11-16    195
# 2012-07-04    194
# 2013-07-04    183
# 2015-07-04    177
# 2011-07-04    158
# 2009-09-19    129
# 2016-07-27    104
# 2014-01-01    103
# 2013-12-31     98
# 2014-07-05     98
# 2004-10-31     94
# 2009-07-04     87
# 2013-07-06     82
# 2014-07-12     77
# 2012-01-01     77
# 2015-09-27     76
# 2013-01-01     74
# Name: count, dtype: int64

# %%
# Crea una nueva columna "DiaMes" que contenga el día y el mes sin tener en cuenta el año
nuforc_99_17['MesDia'] = nuforc_99_17['Event_Date'].dt.strftime('%m-%d')

# Utiliza el método "value_counts" para contar las ocurrencias de cada "DiaMes"
ocurrencias_por_dia_mes = nuforc_99_17['MesDia'].value_counts()

# Ordena las ocurrencias en orden descendente
ocurrencias_por_dia_mes = ocurrencias_por_dia_mes.sort_values(ascending=False)

# Muestra las ocurrencias por día y mes
print(ocurrencias_por_dia_mes)
# Out:
# MesDia
# 07-04    1645
# 01-01     762
# 11-07     541
# 08-15     539
# 12-31     532
#          ...
# 03-24     159
# 03-26     158
# 05-16     157
# 12-19     155
# 02-29      61
# Name: count, Length: 366, dtype: int64

# %%
top_ocurrencias = ocurrencias_por_dia_mes.head(20)
plt.figure(figsize=(12, 6))
top_ocurrencias.plot(kind='bar')
plt.title('Ocurrencias por Día y Mes')
plt.xlabel('Día y Mes')
plt.ylabel('Número de Ocurrencias')
for x, y in enumerate(top_ocurrencias):
    plt.text(x, y, str(y), ha='center', va='bottom')
plt.show()

# %%
pais_elegido = "Spain"
df_pais = nuforc_99_17[nuforc_99_17['State'] == pais_elegido].copy()

# 2. Convierte la columna 'event_date' en un objeto datetime
df_pais['Event_Date'] = pd.to_datetime(df_pais['Event_Date'])

# 3. Crea una nueva columna 'DiaMes' que combine el día y el mes
df_pais['DiaMes'] = df_pais['Event_Date'].dt.strftime('%d-%m')

# 4. Agrupa por 'DiaMes' y cuenta las ocurrencias
conteo_dia_mes = df_pais['DiaMes'].value_counts().sort_index()

# Ordena las ocurrencias en orden descendente
ocurrencias_por_dia_mes = conteo_dia_mes.sort_values(ascending=False)

# Muestra las ocurrencias por día y mes
print('Pais:',pais_elegido,'\n')
print(ocurrencias_por_dia_mes)
# Out:
# Pais: Spain
#
# DiaMes
# 26-01    2
# 20-08    2
# 12-09    2
# 10-04    2
# 14-02    2
#         ..
# 15-12    1
# 16-01    1
# 16-11    1
# 02-08    1
# 30-08    1
# Name: count, Length: 64, dtype: int64

# %%
# gráfico de barras para visualizar las ocurrencias por día y mes
plt.figure(figsize=(15, 6))
conteo_dia_mes.plot(kind='bar', color='blue')
plt.xlabel('Día y Mes')
plt.ylabel('Número de Ocurrencias')
plt.title(f'Ocurrencias en {pais_elegido} por Día y Mes')
plt.xticks(rotation=45)
plt.show()

# %%
# columna 'State' que contiene los estados(USA) y otros países

# Filtra los estados estadounidenses (2 caracteres)
estados_usa = nuforc_99_17[nuforc_99_17['State'].str.len() == 2]['State']

# Cuenta la cantidad de ocurrencias de cada estado estadounidense
conteo_estados_usa = estados_usa.value_counts()

# Filtra los estados y otros países (que no son de 2 caracteres)
estados_paises = nuforc_99_17[nuforc_99_17['State'].str.len() != 2]['State']

# Cuenta la cantidad de ocurrencias de estados y países (excluyendo los de 2 caracteres)
conteo_paises = estados_paises.value_counts()
# Excluye los países con menos de 80 ocurrencias
conteo_paises = conteo_paises[conteo_paises > 80]

# Combina los datos en un solo DataFrame
# conteo_total = pd.concat([conteo_estados_usa, conteo_estados_paises], axis=0)
conteo_paises['USA'] = conteo_estados_usa.sum()


# Crea una lista de etiquetas con el formato "Nombre del Estado (Cantidad)"
etiquetas = [f'{estado} ({ocurrencias})' for estado, ocurrencias in conteo_paises.items()]

# Crea una gráfica squarify
plt.figure(figsize=(10, 6))
squarify.plot(sizes=conteo_paises, label=etiquetas, alpha=0.6)#label=si no conteo_paises.index
plt.axis('off')
plt.title('Estados de Usa (USA) y Países-PERIODO AVISTAMIENTOS 1999-2017')
plt.show()

# %%
plt.figure(figsize=(10, 6))
# plt.yscale('log')
plt.bar('USA', conteo_paises['USA'], color='green', label='USA')
plt.bar(conteo_paises.index, conteo_paises.values, color='gray', label='Otros Países')
plt.xlabel('Número de Ocurrencias')
plt.title('Estados y Países en la columna State')
plt.xticks(rotation=45)
plt.legend()
plt.show()
# NO SALE AZUL

# %%
#La figura mas vista.............NO VA A MEMORIA

# Filtra los estados con más de 60 avistamientos
estados_con_mas_de_60_avistamientos = nuforc_99_17['State'].value_counts()[nuforc_99_17['State'].value_counts() > 60].index

# Filtra el DataFrame original para incluir solo los estados con más de 60 avistamientos
nuforc_filtrado = nuforc_99_17[nuforc_99_17['State'].isin(estados_con_mas_de_60_avistamientos)]

# Agrupa el DataFrame filtrado por estado y forma, y cuenta las ocurrencias
frecuencia_formas_por_estado = nuforc_filtrado.groupby(['State', 'Shape'])['Shape'].count()

# Encuentra la forma más común en cada estado
forma_mas_comun_por_estado = frecuencia_formas_por_estado.groupby('State').idxmax()

# Muestra la forma más común en cada estado
print(forma_mas_comun_por_estado)
# Out:
# State
# AB    (AB, Light)
# AK    (AK, Light)
# AL    (AL, Light)
# AR    (AR, Light)
# AZ    (AZ, Light)
#          ...
# VT    (VT, Light)
# WA    (WA, Light)
# WI    (WI, Light)
# WV    (WV, Light)
# WY    (WY, Light)
# Name: Shape, Length: 73, dtype: object

# %%
nuforc_con_usa = nuforc_99_17.copy()

# Identifica los estados de EE. UU. por su longitud de dos caracteres
estados_usa = nuforc_con_usa['State'].str.len() == 2

# Reemplaza los estados de EE. UU. con "USA"
nuforc_con_usa['State'].loc[estados_usa] = "USA"

# Filtra los estados con más de 60 avistamientos
estados_con_mas_de_60_avistamientos = nuforc_con_usa['State'].value_counts()[nuforc_con_usa['State'].value_counts() > 60].index

# Filtra el DataFrame para incluir solo los estados con más de 60 avistamientos o "USA"
nuforc_filtrado = nuforc_con_usa[nuforc_con_usa['State'].isin(estados_con_mas_de_60_avistamientos)]

# Agrupa el DataFrame filtrado por estado y forma, y cuenta las ocurrencias
frecuencia_formas_por_estado = nuforc_filtrado.groupby(['State', 'Shape'])['Shape'].count()

# Encuentra la forma más común en "USA" y cada estado
forma_mas_comun_por_estado = frecuencia_formas_por_estado.groupby('State').idxmax()

# Muestra la forma más común en "USA" y cada estado
print(forma_mas_comun_por_estado)
# Out:
# State
# Australia          (Australia, Light)
# Germany              (Germany, Light)
# India               (India, Fireball)
# Malaysia             (Malaysia, Disk)
# Mexico                (Mexico, Light)
# Netherlands      (Netherlands, Light)
# New Zealand      (New Zealand, Light)
# Puerto Rico      (Puerto Rico, Light)
# South Africa    (South Africa, Light)
# Spain                 (Spain, Circle)
# UK/England        (UK/England, Light)
# UK/Scotland      (UK/Scotland, Light)
# UK/Wales            (UK/Wales, Light)
# USA                      (USA, Light)
# Name: Shape, dtype: object
# C:\Users\joaqu\AppData\Local\Temp\ipykernel_13292\1969736954.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nuforc_con_usa['State'].loc[estados_usa] = "USA"

# %%
# Copia del DataFrame original
nuforc_data = nuforc_99_17.copy()

# Define una función para obtener la estación del año
def obtener_estacion(mes):
    if 3 <= mes <= 5:
        return "Primavera"
    elif 6 <= mes <= 8:
        return "Verano"
    elif 9 <= mes <= 11:
        return "Otoño"
    else:
        return "Invierno"

# Aplica la función para obtener la estación del año
nuforc_data['Estacion'] = nuforc_data['Month'].apply(obtener_estacion)

# Cuenta los avistamientos en cada estación
avistamientos_por_estacion = nuforc_data['Estacion'].value_counts()

# Ordena las estaciones en orden de las estaciones del año
orden_estaciones = ["Invierno", "Primavera", "Verano", "Otoño"]
avistamientos_por_estacion = avistamientos_por_estacion[orden_estaciones]

# Crea un gráfico de barras para mostrar los avistamientos por estación
avistamientos_por_estacion.plot(kind='bar', figsize=(10, 6))

# Personaliza el gráfico
plt.title("Avistamientos de OVNIs por Estación del Año")
plt.xlabel("Estación del Año")
plt.ylabel("Número de Avistamientos")
plt.xticks(rotation=45)
# Muestra el gráfico
plt.show()

# %%
# Copia del DataFrame original
nuforc_data = nuforc_99_17.copy()

# Cuenta los avistamientos en cada hora del día
avistamientos_por_hora = nuforc_data['Hour'].value_counts().sort_index()

print(avistamientos_por_hora)
'''OJO ESAS HORAS SON ZULU,  y usa es mas del 90 por ciento de los avistamientos
por lo q esas observaciones se deslizarian hacia atras entre 6 horas de media'''
# Out:
# Hour
# 0      5743
# 1      3562
# 2      2458
# 3      2259
# 4      1845
# 5      1965
# 6      1530
# 7      1137
# 8       990
# 9      1179
# 10     1343
# 11     1368
# 12     1497
# 13     1398
# 14     1405
# 15     1519
# 16     1809
# 17     2877
# 18     4861
# 19     7235
# 20    10233
# 21    13710
# 22    12824
# 23     9264
# Name: count, dtype: int64
# 'OJO ESAS HORAS SON ZULU,  y usa es mas del 90 por ciento de los avistamientos\npor lo q esas observaciones se deslizarian hacia atras entre 6 horas de media'

# %%
# Crea un gráfico de barras para mostrar los avistamientos por hora
avistamientos_por_hora.plot(kind='bar', figsize=(12, 6))

# Personaliza el gráfico
plt.title("Avistamientos de OVNIs por Hora del Día")
plt.xlabel("Hora del Día")
plt.ylabel("Número de Avistamientos")
plt.xticks(rotation=0)  # No rotar las etiquetas del eje X

# Muestra el gráfico
plt.show()

# %% [markdown]
# DE AQUI PARA ABAJO NADA A MEMORIA

# %%
# Copia del DataFrame original
nuforc_data = nuforc_99_17.copy()

# Filtra los estados de EE. UU. con más de 60 avistamientos
estados_usa_mas_60 = nuforc_data[nuforc_data['State'].str.len() == 2]['State'].value_counts()[nuforc_data['State'].value_counts() > 60].index

# Filtra los países del mundo con más de 60 avistamientos
paises_mundo_mas_60 = nuforc_data[nuforc_data['State'].str.len() > 2]['State'].value_counts()[nuforc_data['State'].value_counts() > 60].index

# Filtra el DataFrame para incluir solo estados de EE. UU. y países del mundo con más de 60 avistamientos
nuforc_filtrado = nuforc_data[nuforc_data['State'].isin(estados_usa_mas_60) | nuforc_data['State'].isin(paises_mundo_mas_60)]

# Cuenta los avistamientos por estado y país
avistamientos_por_estado = nuforc_filtrado[nuforc_filtrado['State'].str.len() == 2]['State'].value_counts()
avistamientos_por_pais = nuforc_filtrado[nuforc_filtrado['State'].str.len() > 2]['State'].value_counts()

# Encuentra el total de avistamientos
total_avistamientos = len(nuforc_filtrado)

# Calcula el porcentaje de avistamientos por estado y país
porcentaje_por_estado = (avistamientos_por_estado / total_avistamientos) * 100
porcentaje_por_pais = (avistamientos_por_pais / total_avistamientos) * 100

# Crea un nuevo DataFrame con la información
info_df = pd.DataFrame({
    'Ubicación': avistamientos_por_estado.index.tolist() + avistamientos_por_pais.index.tolist(),
    'Avistamientos': avistamientos_por_estado.values.tolist() + avistamientos_por_pais.values.tolist(),
    'Porcentaje (%)': porcentaje_por_estado.values.tolist() + porcentaje_por_pais.values.tolist()
})

# Imprime el nuevo DataFrame
print(info_df)
# Out:
#       Ubicación  Avistamientos  Porcentaje (%)
# 0            CA          10873       11.919143
# 1            FL           5323        5.835151
# 2            WA           4591        5.032722
# 3            TX           3958        4.338818
# 4            NY           3667        4.019820
# ..          ...            ...             ...
# 68      Germany             96        0.105237
# 69  Puerto Rico             74        0.081120
# 70     UK/Wales             73        0.080024
# 71        Spain             73        0.080024
# 72     Malaysia             63        0.069062
#
# [73 rows x 3 columns]

# %%
avistamientos_year = nuforc_99_17['Year'].value_counts()
avistamientos_year
# Out:
# Year
# 2014    8589
# 2012    8024
# 2013    7737
# 2015    6809
# 2011    5550
# 2016    5525
# 2008    5231
# 2009    4927
# 2010    4717
# 2007    4681
# 2004    4674
# 2005    4467
# 2003    4382
# 2006    4099
# 2002    3636
# 2001    3497
# 1999    3131
# 2000    3060
# 2017    1275
# Name: count, dtype: int64

# %%
plt.bar(avistamientos_year.index, avistamientos_year.values, width=3)
# Out:
# <BarContainer object of 19 artists>
